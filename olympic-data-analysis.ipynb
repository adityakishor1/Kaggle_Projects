# %% [markdown]
# **Olympic Data Analysis using Python**

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df= pd.read_csv("/kaggle/input/olympic-data/dataset_olympics.csv")
df

# %%
df.isnull().sum()

# %%
df["Medal"].fillna(0, inplace=True)

# %%
df["Age"].fillna(df["Age"].mean, inplace=True)

# %%
df["Height"].fillna(df["Height"].mean, inplace=True)

# %%
df["Weight"].fillna(df["Weight"].mean, inplace=True)

# %%
df.info()

# %%
Sport=df["Sport"].unique()
for Sports in Sport:
    print("->",Sports)

# %%
column=df.columns
for columns in column:
    print("->", columns)

# %%
df.dtypes
